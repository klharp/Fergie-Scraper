# %% [markdown]
# Change
# 1. config var
# 2. query URL
# 3. csv filename

# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import csv

# Import URL
from config import bath_sink_url

# %%
# Build query to mask url
query_url = f"{bath_sink_url}"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36'}

# %%
r=requests.get(query_url, headers=headers)
soup1 = BeautifulSoup(r.content, 'html5lib')

# %%
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script>
#    window.gtmDataLayer = window.gtmDataLayer || [];window.gtmDataLayer.push({'ssCampaigns':'66507:2275435'});
#   </script>
#   <link data-chunk="main" href="/public/main-090a990399c57b0f2d29.css" rel="stylesheet"/>
#   <link data-chunk="routedcategoryrouter" href="/public/routedcategoryrouter-d0a59e43c909cf99f473.css" rel="stylesheet"/>
#   <link data-chunk="search-results" href="/public/search-results-b6f5a94aabc52b901202.css" rel="stylesheet"/>
#   <script type="text/javascript">
#    window.gtmDataLayer = window.gtmDataLayer || []; window.gtmDataLayer = window.gtmDataLayer.concat([{"siteId":82}]);
#   </script>
#   <script type="text/javascript">
#    window.vizlayer={"type":"other_page"}
#   </script>
#   <script type="text/javascript">
# ...

# %%
# results will return a list
prod_desc = soup1.find_all('div', class_='lh-title normal f5 fw3 fw2-ns tc3-title tc4-title-ns')

# %%
# prod_desc

# %%
# var0=prod_desc[0].text
# print(var0)

# %%
generated_text = []

for i in prod_desc:
    prod_text = i.text.strip()
#     print(prod_text)

    generated_text.append(prod_text)

# %%
df = pd.DataFrame(generated_text, columns= ["Description"])

# %%
df
# Out:
#                                           Description
# 0   Signature Hardware Myers 21" Vitreous China Un...
# 1   Miseno 21-1/16" Undermount Bathroom Sink with ...
# 2   Kohler Verticyl 19-13/16" Rectangular Undermou...
# 3   Miseno 22-7/8" Undermount Bathroom Sink with O...
# 4   Kohler Ladena 20-7/8" x 14-3/8" x 8-1/8" Under...
# 5   Kohler Caxton Rectangle 20-1/4" Undermount Bat...
# 6   Kohler Ladena 23-1/4" Undermount Bathroom Sink...
# 7   Kohler Archer 19-7/8" Undermount Bathroom Sink...
# 8   Signature Hardware 20-1/4" Rectangular Vitreou...
# 9   Kohler Caxton 19-1/4" Undermount Bathroom Sink...
# 10  Signature Hardware Valor 17-5/8" Vessel Bathro...
# 11  TOTO 19" Undermount Bathroom Sink with Overflo...
# 12  Kohler Verticyl 17-1/8" Rectangular Vitreous C...
# 13  Kohler Caxton 17" Undermount Bathroom Sink wit...
# 14  Miseno 19-7/8" Rectangular Undermount Bathroom...
# 15  Kohler Memoirs 24" Pedestal Fireclay Bathroom ...
# ...

# %%
df["Manufacturer"] = df["Description"].str.split(' ').str[0]

# %%
df["Description"] = df["Description"].apply(lambda x: ' '.join(x.split(' ')[1:]))

# %%
# df

# %%
# Add csv export
df.to_csv('data/bath_sink.csv', index=False)
